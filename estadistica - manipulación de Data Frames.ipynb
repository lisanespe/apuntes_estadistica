# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/bodyfat.txt", delimiter = " ", decimal = ".", encoding="utf-8")

# %%
df.head()
# Out:
#    Density   Fat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 1   1.0708  12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 2   1.0853   6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 3   1.0414  25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 4   1.0751  10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 5   1.0340  28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 1  37.3   21.9    32.0     27.4   17.1
# 2  37.3   23.4    30.5     28.9   18.2
# 3  38.9   24.0    28.8     25.2   16.6
# 4  37.3   22.8    32.4     29.4   18.2
# 5  42.2   24.0    32.2     27.7   17.7

# %% [markdown]
# # Acceder a posiciones.

# %%
# Acceder al item por index 
df.loc[1]
# Out:
# Density      1.0708
# Fat         12.3000
# Age         23.0000
# Weight     154.2500
# Height      67.7500
# Neck        36.2000
# Chest       93.1000
# Abdomen     85.2000
# Hip         94.5000
# Thigh       59.0000
# Knee        37.3000
# Ankle       21.9000
# Biceps      32.0000
# Forearm     27.4000
# Wrist       17.1000
# Name: 1, dtype: float64

# %%
# Acceder al Item por posición

df.iloc[[0]]
# Out:
#    Density   Fat  Age  Weight  Height  Neck  Chest  Abdomen   Hip  Thigh  \
# 1   1.0708  12.3   23  154.25   67.75  36.2   93.1     85.2  94.5   59.0
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 1  37.3   21.9    32.0     27.4   17.1

# %%
# Sacar por conjunto de datos.

df[12:20]
# Out:
#     Density   Fat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 13   1.0513  20.8   32  180.50   69.50  38.4  102.0     91.6  103.9   63.4
# 14   1.0505  21.2   30  205.25   71.25  39.4  104.1    101.8  108.6   66.0
# 15   1.0484  22.1   35  187.75   69.50  40.5  101.3     96.4  100.1   69.0
# 16   1.0512  20.9   35  162.75   66.00  36.4   99.1     92.8   99.2   63.1
# 17   1.0333  29.0   34  195.75   71.00  38.9  101.9     96.4  105.2   64.8
# 18   1.0468  22.9   32  209.25   71.00  42.1  107.6     97.5  107.0   66.9
# 19   1.0622  16.0   28  183.75   67.75  38.0  106.8     89.6  102.4   64.2
# 20   1.0610  16.5   33  211.75   73.50  40.0  106.2    100.5  109.0   65.8
#
#     Knee  Ankle  Biceps  Forearm  Wrist
# 13  38.3   21.5    32.5     28.6   17.7
# 14  41.5   23.7    36.9     31.6   18.8
# 15  39.0   23.1    36.1     30.5   18.2
# 16  38.7   21.7    31.1     26.4   16.9
# 17  40.8   23.1    36.2     30.8   17.3
# 18  40.0   24.4    38.2     31.6   19.3
# ...

# %%
# De la 10 a la 95, en conjunto de 5 en 5

df[10:95:5]
# Out:
#     Density   Fat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 11   1.0830   7.1   26  186.25   74.50  38.5  101.5     83.6   98.2   59.7
# 16   1.0512  20.9   35  162.75   66.00  36.4   99.1     92.8   99.2   63.1
# 21   1.0551  19.1   28  179.00   68.00  39.1  103.3     95.9  104.9   63.5
# 26   1.0911   3.7   27  159.25   71.50  35.7   89.6     79.7   96.5   55.0
# 31   1.0716  11.9   32  182.00   73.75  38.7  100.5     88.7   99.8   57.5
# 36   1.0101  40.1   49  191.75   65.00  38.4  118.5    113.1  113.8   61.9
# 41   1.0217  34.5   45  262.75   68.75  43.2  128.3    126.2  125.6   72.5
# 46   1.0670  13.9   43  164.25   73.25  35.7   96.6     81.5   97.2   58.4
# 51   1.0756  10.2   47  158.25   72.25  34.9   90.2     86.7   98.3   52.6
# 56   1.0473  22.6   54  198.00   72.00  39.9  107.6    100.0   99.6   57.2
# 61   1.0396  26.1   62  216.00   73.25  41.4  112.3    104.8  103.1   61.6
# ...

# %%
df.Density.sum()
# Out:
# 266.0046

# %%
df.Density.mean()
# Out:
# 1.0555738095238094

# %%
df.Density.median()
# Out:
# 1.0549

# %%
df.describe().transpose()
# Out:
#          count        mean        std      min       25%       50%       75%  \
# Density  252.0    1.055574   0.019031    0.995    1.0414    1.0549    1.0704
# Fat      252.0   19.150794   8.368740    0.000   12.4750   19.2000   25.3000
# Age      252.0   44.884921  12.602040   22.000   35.7500   43.0000   54.0000
# Weight   252.0  178.924405  29.389160  118.500  159.0000  176.5000  197.0000
# Height   252.0   70.148810   3.662856   29.500   68.2500   70.0000   72.2500
# Neck     252.0   37.992063   2.430913   31.100   36.4000   38.0000   39.4250
# Chest    252.0  100.824206   8.430476   79.300   94.3500   99.6500  105.3750
# Abdomen  252.0   92.555952  10.783077   69.400   84.5750   90.9500   99.3250
# Hip      252.0   99.904762   7.164058   85.000   95.5000   99.3000  103.5250
# Thigh    252.0   59.405952   5.249952   47.200   56.0000   59.0000   62.3500
# Knee     252.0   38.590476   2.411805   33.000   36.9750   38.5000   39.9250
# ...

# %%
# Crear dataframe
import numpy as np

# %%
df2 = pd.DataFrame({
    'A': np.random.rand(10),
    'B': np.random.rand(10),
    'C': np.random.rand(10)
})

# %%
df.mean(axis='columns')
# Out:
# 0    0.327019
# 1    0.496028
# 2    0.577947
# 3    0.541933
# 4    0.544913
# 5    0.049844
# 6    0.445997
# 7    0.591746
# 8    0.945726
# 9    0.563837
# dtype: float64

# %%
df2 = pd.DataFrame({
    'key' : ['A', 'B', 'C', 'A', 'B',  'C'],
    'values': range(6)
}, 
columns = ['key', 'values']
)

# %%
df2.groupby('key').mean()
# Out:
#      values
# key
# A       1.5
# B       2.5
# C       3.5

# %% [markdown]
# # Manipulacion de DataFrames

# %%
df3 = pd.DataFrame({
    'key' : ['A', 'B', 'C', 'A', 'B',  'C'],
    'value1': range(6),
    'value2': np.random.randint(0,100,6)
})

# %%
df3
# Out:
#   key  value1  value2
# 0   A       0      97
# 1   B       1      51
# 2   C       2       8
# 3   A       3      57
# 4   B       4      23
# 5   C       5      60

# %% [markdown]
# # Aggregate

# %%
df3.groupby('key').aggregate(['min', np.median, np.mean, max])
# Out:
#     value1                 value2
#        min median mean max    min median mean max
# key
# A        0    1.5  1.5   3     57     77   77  97
# B        1    2.5  2.5   4     23     37   37  51
# C        2    3.5  3.5   5      8     34   34  60

# %%
df3.groupby('key').aggregate({
    'value1': 'min',
    'value2': 'max'    
})
# Out:
#      value1  value2
# key
# A         0      97
# B         1      51
# C         2      60

# %% [markdown]
# # Filter

# %%
def filter_func(x):
    return x['value2'].std()>5

# %%
df3.groupby('key').filter(filter_func)
# Out:
#   key  value1  value2
# 0   A       0      97
# 1   B       1      51
# 2   C       2       8
# 3   A       3      57
# 4   B       4      23
# 5   C       5      60

# %%
df3.groupby('key').transform(lambda x: x - x.mean())
# Out:
#    value1  value2
# 0    -1.5    20.0
# 1    -1.5    14.0
# 2    -1.5   -26.0
# 3     1.5   -20.0
# 4     1.5   -14.0
# 5     1.5    26.0

# %% [markdown]
# ## Apply

# %%
def norm_by_col2(x):
    x['value1'] /= x['value2'].sum()  # o lo que es igual: x['value1']= x['value1']/x['value2'].sum()
    return x

# %%
df3.groupby('key').apply(norm_by_col2)
# Out:
#   key    value1  value2
# 0   A  0.000000      97
# 1   B  0.013514      51
# 2   C  0.029412       8
# 3   A  0.019481      57
# 4   B  0.054054      23
# 5   C  0.073529      60

# %% [markdown]
# # División de datos por columnas

# %%
L = [0,1,0,1,2,0] #Etiquetas
print(df3)
df3.groupby(L).sum()
# Out:
#   key  value1  value2
# 0   A       0      97
# 1   B       1      51
# 2   C       2       8
# 3   A       3      57
# 4   B       4      23
# 5   C       5      60
#    value1  value2
# 0       7     165
# 1       4     108
# 2       4      23

# %%
df3 = df3.set_index('key')
df3
# Out:
#      value1  value2
# key
# A         0      25
# B         1      91
# C         2      37
# A         3      26
# B         4      36
# C         5      18

# %%
mapping = {
    'A': 'vowel',
    'B': 'consonant',
    'C': 'consonant'
}

# %%
df3.groupby(mapping).sum()
# Out:
#            value1  value2
# consonant      12     182
# vowel           3      51

# %%
df3.groupby(str.lower).mean()
# Out:
#    value1  value2
# a     1.5    25.5
# b     2.5    63.5
# c     3.5    27.5

# %%
df3.groupby([str.lower, mapping]).mean()
# Out:
#              value1  value2
# a vowel         1.5    25.5
# b consonant     2.5    63.5
# c consonant     3.5    27.5

# %% [markdown]
# # Gráficos desde data frames y exportación

# %%
import numpy as np
years = [year for year in range(1900,2020)]
deads = [(y + np.random.uniform(0,1000)- 1850) for y in years]

# %%
df = pd.DataFrame({
    "year": years,
    "deads": deads 
    
})

# %%
my_plot = df.plot(x='year', y = 'deads', figsize = (10,8))

# %%
my_fig = my_plot.get_figure()

# %%
my_fig.savefig('gráfico.png')
