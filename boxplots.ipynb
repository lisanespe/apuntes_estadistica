# %% [markdown]
# # Diagrama de caja y bigotes

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(19880519)

# %%
dist1 = 100 * np.random.rand(50)
dist2 = 50 * np.ones(25)
dist3 = 100+100*np.random.rand(10)
dist4 = -100*np.random.rand(10)
data = np.concatenate((dist1, dist2, dist3, dist4))

# %%
fig1, ax1 =plt.subplots()
ax1.set_title('Boxplot básico')
ax1.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fb7d7ace518>,
#   <matplotlib.lines.Line2D at 0x7fb7d7ace860>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fb7d7aceba8>,
#   <matplotlib.lines.Line2D at 0x7fb7d7aceef0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fb7d7ace0f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fb7d7acefd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fb7d7adc5c0>],
#  'means': []}

# %%
fig2, ax2 =plt.subplots()
ax2.set_title('Boxplot básico')
ax2.boxplot(data, notch = True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fb7d7941898>,
#   <matplotlib.lines.Line2D at 0x7fb7d7941be0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fb7d7941f28>,
#   <matplotlib.lines.Line2D at 0x7fb7d794b2b0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fb7d7941470>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fb7d794b5f8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fb7d794b940>],
#  'means': []}

# %%
green_diamond = dict(markerfacecolor = "g", marker = "D")

fig3, ax3 =plt.subplots()
ax3.set_title('Boxplot básico con outliers personalizados')
ax3.boxplot(data, flierprops = green_diamond)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fb7d7813860>,
#   <matplotlib.lines.Line2D at 0x7fb7d7813ba8>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fb7d7813ef0>,
#   <matplotlib.lines.Line2D at 0x7fb7d7813fd0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fb7d7813438>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fb7d781c5c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fb7d781c908>],
#  'means': []}

# %%
fig4, ax4 =plt.subplots()
ax4.set_title('Boxplot sin outliers')
ax4.boxplot(data, showfliers = False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fb7d77ee400>,
#   <matplotlib.lines.Line2D at 0x7fb7d77ee748>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fb7d77eea90>,
#   <matplotlib.lines.Line2D at 0x7fb7d77eedd8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fb7d77e5f98>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fb7d77eeeb8>],
#  'fliers': [],
#  'means': []}

# %%
red_square = dict(markerfacecolor="r", marker = "s") 
fig5, ax5 =plt.subplots()
ax5.set_title('Boxplot personalizado y en horizontal')
ax5.boxplot(data, vert = False, flierprops=red_square, whis=0.75) #acomodar los bigotes
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fb7d795d358>,
#   <matplotlib.lines.Line2D at 0x7fb7d795d898>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fb7d794bf60>,
#   <matplotlib.lines.Line2D at 0x7fb7d79d8a20>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fb7d795d9b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fb7d79d83c8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fb7d79d86a0>],
#  'means': []}
